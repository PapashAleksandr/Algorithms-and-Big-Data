# %% [markdown]
# Hometask #1
# 1. Upload qm9.csv dataset on your server
# 2. Find your personal random state in the “students list” table
# 3. Sample 20k rows from qm9 dataset using your personal random state

# %%
import pandas as pd

# %%
df = pd.read_csv('qm9.csv')
df
# Out:
#             mol_id               smiles          A           B           C  \
# 0            gdb_1                    C  157.71180  157.709970  157.706990
# 1            gdb_2                    N  293.60975  293.541110  191.393970
# 2            gdb_3                    O  799.58812  437.903860  282.945450
# 3            gdb_4                  C#C    0.00000   35.610036   35.610036
# 4            gdb_5                  C#N    0.00000   44.593883   44.593883
# ...            ...                  ...        ...         ...         ...
# 133880  gdb_133881  C1C2C3C4C5OC14C5N23    3.59483    2.198990    1.904230
# 133881  gdb_133882  C1N2C3C2C2C4OC12C34    3.65648    2.142370    1.904390
# 133882  gdb_133883  C1N2C3C4C5C2C13CN45    3.67118    2.143140    1.895010
# 133883  gdb_133884  C1N2C3C4C5CC13C2C45    3.52845    2.151310    1.865820
# 133884  gdb_133885  C1N2C3C4C5OC13C2C45    3.64015    2.217640    1.937930
#
# ...

# %%
new_df = df.sample(n=20000, random_state=32)

# %%
new_df
# Out:
#             mol_id              smiles        A        B        C      mu  \
# 108561  gdb_108562     OCC12CCC3CC1N23  3.14659  1.48282  1.26334  2.2697
# 101228  gdb_101229     CC1CC(C1)C(O)CO  3.77875  0.79159  0.71331  2.4119
# 10481    gdb_10482       CCC1(CC1)CC#C  2.56446  1.63607  1.20968  0.5547
# 49391    gdb_49392   O=CC1C2C3C1C2C3=O  6.74489  0.94812  0.91985  0.4739
# 16341    gdb_16342        COC12CC1CC2C  2.92787  1.88138  1.43518  0.8976
# ...            ...                 ...      ...      ...      ...     ...
# 3612      gdb_3613      C1C2C3CC=C1C23  4.95043  3.63948  2.72594  0.9240
# 6497      gdb_6498      CC(C)CC1(CC1)C  3.30269  1.23795  1.09358  0.0583
# 113387  gdb_113388       CCC1OC1(CO)CO  2.99823  0.96374  0.81546  2.8254
# 97890    gdb_97891     C(C#CCO)C(=O)CO  6.22510  0.51084  0.49047  2.4684
# 123871  gdb_123872  c1c(cn[nH]1)N2CCC2  5.03077  1.05223  0.89806  2.6379
#
#         alpha    homo    lumo     gap         r2      zpve          u0  \
# ...

# %%
new_df.to_csv('df1.csv')
